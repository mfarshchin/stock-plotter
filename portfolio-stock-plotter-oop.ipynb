# %% [markdown]
# ## This notebook is to analyze and plot history of all stocks in a portfolio

# %%
from class_info import *
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1001">Loading BokehJS ...</span>
#     </div>

# %% [markdown]
# ### portfolio information

# %%
# key:   `stock name`
# value: `purchase price`
# e.g. portfolio = {'QS':40, 'GE':100, 'MSFT':''}

portfolio = {'PTON':47.26,
             'AAL':19.55,
             'ARKK':112.55, 
             'EXPI':41.05, 
             'GE':103.15, 
             'IBM':121.06, 
             'AI': 42.60,  
             'CRSP':87.30, 
             'TWTR':53.92, 
             'JAGX':2.396, 
             'WKHS':7.64, 
             'QS':30.66, 
             'SNDL':0.8493, 
             'NKLA':13.69, 
             'CANG':6.88}

# %%
for name, price in portfolio.items():
    history_plot(name, purchase_price=price, ma=[50])
# Out:
#   <div class="bk-root" id="6eced5d0-dfd4-4678-b25e-0a867c82d020" data-root-id="1002"></div>
#   <div class="bk-root" id="2719b977-b6ac-4ec1-a1a3-35ba62a237ad" data-root-id="1381"></div>
#   <div class="bk-root" id="4cd5154a-51f7-4f76-a370-19e27f4d6093" data-root-id="1825"></div>
#   <div class="bk-root" id="ddf65dea-8012-4368-91d1-4f426fdcf01f" data-root-id="2298"></div>
#   <div class="bk-root" id="3f709943-206c-4f0e-9c3e-f6f7351d46ed" data-root-id="2784"></div>
#   <div class="bk-root" id="d5ffed27-1e28-491d-9978-b60c9996d2f9" data-root-id="3315"></div>
#   <div class="bk-root" id="c9a8854f-0451-457d-8acd-b151c4262854" data-root-id="3875"></div>
#   <div class="bk-root" id="af52f903-a9df-4798-9677-9d6e877ced8a" data-root-id="4412"></div>
#   <div class="bk-root" id="204aae23-f782-4834-91ea-bd80cba2c93b" data-root-id="5030"></div>
#   <div class="bk-root" id="d2c330dc-59d9-4698-823a-196a73d0b20f" data-root-id="5677"></div>
# ...
